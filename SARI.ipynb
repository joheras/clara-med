# %% [markdown]
# <a href="https://colab.research.google.com/github/joheras/clara-med/blob/main/SARI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets evaluate transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 52.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 18.4 MB/s eta 0:00:00

# %%
# !pip install sacrebleu sacremoses -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 60.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("lcampillos/CLARA-MeD")
# Out:
# ...
# WARNING:datasets.builder:Using custom data configuration lcampillos--CLARA-MeD-b7dbae52585dda58
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/lcampillos___csv/lcampillos--CLARA-MeD-b7dbae52585dda58/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
test_set = dataset["train"].shuffle(seed=5)[int(3800*0.8):]

# %% [markdown]
# mt5-small-clara-med

# %%
from transformers import pipeline

# %%
summarizer = pipeline("text2text-generation", model='joheras/mt5-small-clara-med')
# Out:
# Downloading:   0%|          | 0.00/773 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/453 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/74.0 [00:00<?, ?B/s]

# %%
from evaluate import load
sari = load("sari")

# %%
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# {'sari': 40.70946410993425}

# %% [markdown]
# mt5-simplification-spanish-clara-med

# %%
summarizer = pipeline("text2text-generation", model='joheras/mt5-simplification-spanish-clara-med')
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# Downloading:   0%|          | 0.00/794 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/479 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# {'sari': 41.21584542040843}

# %% [markdown]
# joheras/flan-t5-large-clara-med

# %%
summarizer = pipeline("text2text-generation", model='joheras/flan-t5-large-clara-med')
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# Downloading:   0%|          | 0.00/787 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# {'sari': 39.17315801534282}

# %% [markdown]
# joheras/flan-t5-base-clara-med

# %%
summarizer = pipeline("text2text-generation", model='joheras/flan-t5-base-clara-med')
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# Downloading:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# {'sari': 42.30457540723045}

# %%
summarizer = pipeline("text2text-generation", model='joheras/NASES-clara-med')
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# Downloading:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.66G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/616k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.66M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/957 [00:00<?, ?B/s]
# {'sari': 49.533305860867735}

# %%
summarizer = pipeline("text2text-generation", model='joheras/marimari-r2r-mlsum-clara-med')
# Out:
# Downloading:   0%|          | 0.00/5.08k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/615M [00:00<?, ?B/s]
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ca599d2ae999> in <module>
#       1 summarizer = pipeline("text2text-generation", model='joheras/marimari-r2r-mlsum-clara-med')
#       2 sources = test_set['SOURCE']
# ----> 3 predictions = summarizer(test_set['SOURCE'])
#       4 predictions = [x['generated_text'] for x in predictions]
#       5 references = [[x] for x in test_set['TARGET']]
#
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     163         """
#     164
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("IIC/marimari-r2r-mlsum")
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/851k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/509k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.21M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/594 [00:00<?, ?B/s]

# %%
summarizer.tokenizer = tokenizer

# %%
sources = test_set['SOURCE']
predictions = summarizer(test_set['SOURCE'])
predictions = [x['generated_text'] for x in predictions]
references = [[x] for x in test_set['TARGET']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-229593fa5192> in <module>
#       3 predictions = [x['generated_text'] for x in predictions]
#       4 references = [[x] for x in test_set['TARGET']]
# ----> 5 sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
#       6 print(sari_score)
#
# NameError: name 'sari' is not defined

# %%
sari_score = sari.compute(sources=sources, predictions=predictions, references=references)
print(sari_score)
# Out:
# {'sari': 47.704655250496174}
